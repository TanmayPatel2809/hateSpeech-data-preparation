# %%
import pandas as pd

# %%
df = pd.read_parquet("gs://my_bucket_2003/hate_speech_data/processed/rebalanced_splits/dev.parquet")

# %%
df[df["cleaned_text"].str.split().apply(len) < 2]
# Out:
# Empty DataFrame
# Columns: [text, split, dataset_name, label, cleaned_text]
# Index: []

# %%
len(df)
# Out:
# 17934
